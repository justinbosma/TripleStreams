# %%
from random import random

from hvo_sequence.io_helpers import load_HVO_Sequence_from_file
# Out:
# /Users/bezha/anaconda3/envs/TripleStreams/lib/python3.9/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
grouping_types = ["AllAvailableStreams"]

# %%
import os
root_dir = "data/triple_streams/bongosero_hvo_sequences_single_voices_organized_by_attempts"

# search and compile all folders that end in _{grouping_type} in the root_dir
subfolder_dict = {grouping_type: [] for grouping_type in grouping_types}

# subfolders will be formatted as "data/triple_streams/elbg_merged_hvo/***_hvo"
for grouping_type in grouping_types:
    subfolder = os.path.join(root_dir, f"*")
    subfolder_dict[grouping_type] = [f for f in os.listdir(root_dir) if 'DS_Store' not in f]
    subfolder_dict[grouping_type] = subfolder_dict[grouping_type] #[:10]  # Limit to first 10 for testing
print(subfolder_dict)
# Out:
# {'AllAvailableStreams': ['8337_attempt3', '9413_attempt1', '8385_attempt0', '2192_attempt0', '4654_attempt0', '8072_attempt1', '3794_attempt0', '9913_attempt0', '9588_attempt1', '3969_attempt1', '8740_attempt1', '10050_attempt0', '2730_attempt1', '10236_attempt0', '1708_attempt0', '3469_attempt0', '1082_attempt2', '4222_attempt2', '5760_attempt0', '6325_attempt2', '9147_attempt1', '4045_attempt2', '1257_attempt1', '5761_attempt0', '1354_attempt0', '8924_attempt1', '9222_attempt0', '5663_attempt1', '1355_attempt0', '4918_attempt3', '9166_attempt2', '5904_attempt0', '8337_attempt4', '1276_attempt2', '6162_attempt1', '1082_attempt5', '7808_attempt1', '9228_attempt1', '5151_attempt1', '1234_attempt4', '9451_attempt0', '8844_attempt5', '9450_attempt0', '1740_attempt0', '4786_attempt0', '5010_attempt1', '8544_attempt4', '6710_attempt1', '10546_attempt1', '1663_attempt2', '5118_attempt6', '10018_attempt0', '4349_attempt0', '6028_attempt0', '10547_attempt1', '8708_attempt1', '6029_attempt0', '4125_attempt1', '4343_attempt1', '8565_attempt0', '10275_attempt1', '2515_attempt0', '6245_attempt1', '2773_attempt0', '3498_attempt2', '2436_attempt2', '10356_attempt3', '9878_attempt2', '5790_attempt2', '2586_attempt0', '9558_attempt0', '8544_attempt3', '5118_attempt1', '4027_attempt0', '1287_attempt0', '7604_attempt2', '8844_attempt2', '3381_attempt0', '10377_attempt0', '1234_attempt3', '5790_attempt5', '3822_attempt0', '10356_attempt4', '10445_attempt0', '9348_attempt2', '4451_attempt2', '10275_attempt6', '9787_attempt2', '6801_attempt0', '3456_attempt0', '5774_attempt5', '3098_attempt0', '7296_attempt0', '5391_attempt0', '3021_attempt2', '8983_attempt0', '4153_attempt1', '10147_attempt3', '8656_attempt2', '5533_attempt1', '8580_attempt0', '9070_attempt1', '1458_attempt0', '3738_attempt0', '2796_attempt0', '10044_attempt2', '1361_attempt1', '9749_attempt0', '2960_attempt0', '3266_attempt1', '7837_attempt1', '5774_attempt2', '6899_attempt1', '9152_attempt3', '4768_attempt1', '10166_attempt0', '7672_attempt2', '4769_attempt1', '5299_attempt0', '5292_attempt1', '7395_attempt1', '6892_attempt0', '10432_attempt0', '6664_attempt0', '10147_attempt4', '4494_attempt1', '10933_attempt1', '4426_attempt2', '3021_attempt5', '11112_attempt0', '3884_attempt1', '11113_attempt0', '1298_attempt3', '9019_attempt2', '5361_attempt2', '3914_attempt0', '8736_attempt1', '5571_attempt0', '1989_attempt0', '2388_attempt1', '5249_attempt1', '4254_attempt2', '3042_attempt0', '10006_attempt3', '7574_attempt1', '1145_attempt0', '1298_attempt4', '4274_attempt1', '5784_attempt0', '8452_attempt0', '2176_attempt0', '9691_attempt1', '4254_attempt5', '2311_attempt0', '6441_attempt1', '2177_attempt0', '4189_attempt1', '4847_attempt0', '2929_attempt0', '5478_attempt0', '9700_attempt0', '1410_attempt0', '1880_attempt0', '1287_attempt1', '4027_attempt1', '7604_attempt3', '10377_attempt1', '3381_attempt1', '1234_attempt2', '8844_attempt3', '8544_attempt2', '5118_attempt0', '9558_attempt1', '9878_attempt4', '5790_attempt4', '3401_attempt2', '10445_attempt1', '10356_attempt5', '2436_attempt4', '6028_attempt1', '4349_attempt1', '1827_attempt0', '1663_attempt3', '10546_attempt0', '6710_attempt0', '10547_attempt0', '8708_attempt0', '8844_attempt4', '3318_attempt0', '1740_attempt1', '5010_attempt0', '9450_attempt1', '7604_attempt4', '10356_attempt2', '2436_attempt3', '8693_attempt0', '3498_attempt3', '9878_attempt3', '5790_attempt3', '4125_attempt0', '4343_attempt0', '4858_attempt2', '10275_attempt0', '2773_attempt1', '1384_attempt0', '6245_attempt0', '8337_attempt5', '4918_attempt2', '6162_attempt0', '8924_attempt0', '5404_attempt0', '5663_attempt0', '10525_attempt2', '9228_attempt0', '5151_attempt0', '6984_attempt2', '10407_attempt0', '4530_attempt0', '10660_attempt0', '7808_attempt0', '1082_attempt4', '8072_attempt0', '1446_attempt2', '5649_attempt2', '2192_attempt1', '8385_attempt1', '9413_attempt0', '8337_attempt2', '1082_attempt3', '3469_attempt1', '1708_attempt1', '5761_attempt1', ' ...

# %%
# load all files in the dictionary above, use tqdm to show progress
# also the key in the subdictionary is file name without the _{grouping_type}.hvo

# i want the dict to look like this for eg.
# loaded_hvos = {"velocity": {"1_funk-groove1_138_beat_4-4": "filenames": [], "hvo_sequences": []},

import tqdm
from hvo_sequence.io_helpers import load_HVO_Sequence_from_file
loaded_hvos = {grouping_type: {} for grouping_type in grouping_types}

for grouping_type, subfolders in subfolder_dict.items():
    for subfolder in subfolders:
        # remove the _{grouping_type} from the folder name
        subfolder_name = subfolder.replace(f"_{grouping_type}", "")
        loaded_hvos[grouping_type].update({subfolder_name: {
            "filenames": [],
            "hvo_sequences": [],
            "compiled_single_hvos": [],
            "split_n_bar_phrases": None
        }})

# add filenames and hvo_sequences to the dict
for grouping_type, subfolders in subfolder_dict.items():
    print(f"Loading {grouping_type}")
    for subfolder in tqdm.tqdm(subfolders):
        # remove the _{grouping_type} from the folder name
        subfolder_name = subfolder.replace(f"_{grouping_type}", "")
        hvo_files = [f for f in os.listdir(os.path.join(root_dir, subfolder)) if f.endswith('.hvo')]

        for hvo_file in hvo_files:
            hvo_seq = load_HVO_Sequence_from_file(os.path.join(root_dir, subfolder, hvo_file))
            loaded_hvos[grouping_type][subfolder_name]["filenames"].append(hvo_file)
            loaded_hvos[grouping_type][subfolder_name]["hvo_sequences"].append(hvo_seq)
# Out:
# Loading AllAvailableStreams
# 100%|██████████| 2243/2243 [00:01<00:00, 1343.18it/s]

# %%
# Dictionary structure of loaded_hvos

def get_loaded_hvos_text_description(loaded_hvos, title="Lack MIDI"):
    text = f'{title}\n\n'
    text += "Dictionary Structure:\n"
    
    for grouping_type, hvo_dict in loaded_hvos.items():
        text += f"{grouping_type}:\n"
        cnt = 0
        for subfolder_name, subfolder_data in hvo_dict.items():
            text += (f"    |-------> {subfolder_name} ({len(subfolder_data['filenames'])} files) \n")
            text += (f"    |          |-------> {subfolder_name} \n")
            text += (f"    |                     |--> 'filenames:' \n")

            for i, filename in enumerate(subfolder_data["filenames"]):
               text += (f"    |                           |-------> {filename} \n")

            text +=(f"    |                     |--> 'hvo_sequences:'\n")
            for i, hvo_seq in enumerate(subfolder_data["hvo_sequences"]):
                text +=(f"    |                           |-------> {hvo_seq.hvo.shape[0]} steps, i.e. {hvo_seq.hvo.shape[0] // 16} bars.\n")

            text += (f"    |                     |--> 'compiled_single_hvos:'\n")
            text += (f"    |                               |-------> {loaded_hvos[grouping_type][subfolder_name]['compiled_single_hvos']}\n")

            text += (f"    |                     |--> 'split_n_bar_phrases:'\n")
            text += (f"    |                               |-------> {loaded_hvos[grouping_type][subfolder_name]['split_n_bar_phrases']}\n")

            text += (f"    |-------> ...\n")
            text += ("\n")

            cnt+= 1
            if cnt > 5:  # Limit to first 5 subfolders for readability
                break
    
    return text

print(get_loaded_hvos_text_description(loaded_hvos))
# Out:
# Lack MIDI
#
# Dictionary Structure:
# AllAvailableStreams:
#     |-------> 8337_attempt3 (4 files)
#     |          |-------> 8337_attempt3
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 9413_attempt1 (4 files)
#     |          |-------> 9413_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 8385_attempt0 (4 files)
#     |          |-------> 8385_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 2192_attempt0 (4 files)
#     |          |-------> 2192_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 4654_attempt0 (4 files)
#     |          |-------> 4654_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 8072_attempt1 (4 files)
#     |          |-------> 8072_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...

# %%
# adjust all loaded HVO sequences to the same length
for grouping_type, hvo_dict in loaded_hvos.items():
    for subfolder_name, subfolder_data in hvo_dict.items():
        # Find the maximum length of HVO sequences in this subfolder
        max_length = max(hvo_seq.hvo.shape[0] for hvo_seq in subfolder_data["hvo_sequences"])

        # Adjust each HVO sequence to the maximum length
        for i, hvo_seq in enumerate(subfolder_data["hvo_sequences"]):
            hvo_seq.adjust_length(max(max_length, 32))

# reprint
print(get_loaded_hvos_text_description(loaded_hvos))
# Out:
# Lack MIDI
#
# Dictionary Structure:
# AllAvailableStreams:
#     |-------> 8337_attempt3 (4 files)
#     |          |-------> 8337_attempt3
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 9413_attempt1 (4 files)
#     |          |-------> 9413_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 8385_attempt0 (4 files)
#     |          |-------> 8385_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 2192_attempt0 (4 files)
#     |          |-------> 2192_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 4654_attempt0 (4 files)
#     |          |-------> 4654_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...
#
#     |-------> 8072_attempt1 (4 files)
#     |          |-------> 8072_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> []
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> None
#     |-------> ...

# %%
# Get a random grouping type and a random file name from that grouping type
import random
from hvo_sequence.hvo_seq import HVO_Sequence

def compile_four_hvo_streams_into_single_hvo(seperate_hvo_seqs_, filenames_, participant_number):
    voice_mapping = {
    'stream_0': [36],
    'stream_1': [38],
    'stream_2': [42],
    'stream_3': [46]
    }

    time_sigs = seperate_hvo_seqs_[-1].time_signatures
    tempos = seperate_hvo_seqs_[-1].tempos

    # max length of all HVO sequences

    single_compiled_hvo_seq = HVO_Sequence(
        beat_division_factors=[4],
        drum_mapping=voice_mapping
    )

    for time_sig in time_sigs:
        single_compiled_hvo_seq.add_time_signature(time_step=time_sig.time_step, numerator=time_sig.numerator, denominator=time_sig.denominator)
    for tempo in tempos:
        single_compiled_hvo_seq.add_tempo(time_step=tempo.time_step, qpm=tempo.qpm)

    max_length = max(hvo_seq.hvo.shape[0] for hvo_seq in seperate_hvo_seqs_)
    single_compiled_hvo_seq.adjust_length(max_length)

    metadata_ = {}
    metadata_.update(seperate_hvo_seqs_[-1].metadata)
    metadata_.update({"participant_number": participant_number.split("_")[0]})
    metadata_.update({"attempt": participant_number.split("_attempt")[-1]})

    metadata_.update({f'stream_{ix}': filenames_[ix].split("_")[-1].replace(".hvo", "") for ix in range(len(filenames_))})
    n_streams = single_compiled_hvo_seq.hvo.shape[-1] // 3
    for ix, hvo_stream_seq_ in enumerate(seperate_hvo_seqs_):
        hvo_stream_seq_type = filenames_[ix].replace(".hvo", "")
        metadata_[f'stream_{ix}'] = hvo_stream_seq_type
        single_compiled_hvo_seq.hvo[:, ix] = hvo_stream_seq_.hvo[:, 0]
        single_compiled_hvo_seq.hvo[:, ix+n_streams] = hvo_stream_seq_.hvo[:, hvo_stream_seq_.hvo.shape[1] // 3]
        single_compiled_hvo_seq.hvo[:, ix+n_streams*2] = hvo_stream_seq_.hvo[:, 2 * hvo_stream_seq_.hvo.shape[1] // 3]

    single_compiled_hvo_seq.metadata.update(metadata_)

    return single_compiled_hvo_seq

import itertools

def get_combinations_of_four_hvo_streams(seperate_hvo_seqs_, filenames_):
    seperate_hvo_seqs_four_streams = []
    filenames_four_streams = []
    # get all combinations of four HVO sequences (without repetition)
    for combination in itertools.combinations(zip(seperate_hvo_seqs_, filenames_), 4):
        hvo_streams_combination, filenames_combination = zip(*combination)
        if len(hvo_streams_combination) == 4:
            seperate_hvo_seqs_four_streams.append(list(hvo_streams_combination))
            filenames_four_streams.append(list(filenames_combination))
    return seperate_hvo_seqs_four_streams, filenames_four_streams

# %%
# populate the compiled_single_hvo for each grouping type (use tqdm to show progress)
#
for grouping_type, hvo_dict in loaded_hvos.items():
    for subfolder_name, subfolder_data in tqdm.tqdm(hvo_dict.items()):
        filenames = subfolder_data["filenames"]
        seperate_hvo_seqs = subfolder_data["hvo_sequences"]
        grouped_hvos, grouped_filenames = get_combinations_of_four_hvo_streams(seperate_hvo_seqs, filenames)
        loaded_hvos[grouping_type][subfolder_name]["compiled_single_hvos"] = []
        for i in range(len(grouped_hvos)):
            seperate_hvo_seqs_ = grouped_hvos[i]
            filenames_ = grouped_filenames[i]
            # compile the HVO sequences into a single HVO sequence
            compiled_single_hvo = compile_four_hvo_streams_into_single_hvo(seperate_hvo_seqs_, filenames_, subfolder_name)
            loaded_hvos[grouping_type][subfolder_name]["compiled_single_hvos"].append(compiled_single_hvo)

# reprint



print(get_loaded_hvos_text_description(loaded_hvos))
# Out:
# 100%|██████████| 2243/2243 [00:00<00:00, 7240.01it/s]
# Lack MIDI
#
# Dictionary Structure:
# AllAvailableStreams:
#     |-------> 8337_attempt3 (4 files)
#     |          |-------> 8337_attempt3
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533aeb0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x1770099d0>]
#     |-------> ...
#
#     |-------> 9413_attempt1 (4 files)
#     |          |-------> 9413_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533a310>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3142c1b20>]
#     |-------> ...
#
#     |-------> 8385_attempt0 (4 files)
#     |          |-------> 8385_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533a1c0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3118af1f0>]
#     |-------> ...
#
#     |-------> 2192_attempt0 (4 files)
#     |          |-------> 2192_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531d880>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x316830d30>]
#     |-------> ...
#
#     |-------> 4654_attempt0 (4 files)
#     |          |-------> 4654_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531db20>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x31413b520>]
#     |-------> ...
#
#     |-------> 8072_attempt1 (4 files)
#     |          |-------> 8072_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531ddc0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3140350d0>]
#     |-------> ...

# %%
# loaded_hvos['AllAvailableStreams']['3ca0f5bf8a30195c5e2f62f10a894c1d']['compiled_single_hvos'][0].to_html_plot(
#     filename="hvo_1.html",
#     save_figure=False,
#     show_figure=True)
# loaded_hvos['AllAvailableStreams']['3ca0f5bf8a30195c5e2f62f10a894c1d']['compiled_single_hvos'][-1].to_html_plot(
#     filename="hvo_1.html",
#     save_figure=False,
#     show_figure=True)

# %%
# Split in two bar phrases, with a hop size of 16.

def split_into_n_bar_phrases(hvo_seq, n_bars=2, hop_size=16):
    """
    Split the HVO sequence into n-bar phrases with a hop size.
    Returns a list of HVO sequences.
    """
    n_steps_per_bar = hvo_seq.grid_maker.n_steps_per_beat * 4  # Assuming 4/4 time signature
    n_steps_per_phrase = n_steps_per_bar * n_bars

    phrases = []

    for start in range(0, hvo_seq.hvo.shape[0] - n_steps_per_phrase + 1, hop_size):
        end = start + n_steps_per_phrase
        phrase_hvo = hvo_seq.copy_empty()
        phrase_hvo.adjust_length(n_steps_per_phrase)
        phrase_hvo.hvo[:n_steps_per_phrase, :] = hvo_seq.hvo[start:end, :]
        phrase_hvo.metadata.update({'start_bar': start // n_steps_per_bar})
        phrases.append(phrase_hvo)

    return phrases

for grouping_type, hvo_dict in loaded_hvos.items():
    for subfolder_name, subfolder_data in tqdm.tqdm(hvo_dict.items()):
        loaded_hvos[grouping_type][subfolder_name]["split_n_bar_phrases"] = []
        compiled_single_hvos = subfolder_data["compiled_single_hvos"]
        for compiled_single_hvo in compiled_single_hvos:
            split_n_bar_phrases = split_into_n_bar_phrases(compiled_single_hvo, n_bars=2, hop_size=16)
            loaded_hvos[grouping_type][subfolder_name]["split_n_bar_phrases"].extend(split_n_bar_phrases)

# reprint

import pickle, bz2
# Save the loaded_hvos dictionary to a compressed file
os.makedirs("data/triple_streams/split_2bars", exist_ok=True)
with bz2.BZ2File("data/triple_streams/split_2bars/elbg.pkl.bz2", "wb") as f:
    pickle.dump(loaded_hvos, f)
# Out:
# 100%|██████████| 2243/2243 [00:00<00:00, 16984.45it/s]

# %%
# save the description text to a file
with open("data/triple_streams/split_2bars/elbg_description.txt", "w") as f:
    f.write(get_loaded_hvos_text_description(loaded_hvos))


print(get_loaded_hvos_text_description(loaded_hvos))
# Out:
# Lack MIDI
#
# Dictionary Structure:
# AllAvailableStreams:
#     |-------> 8337_attempt3 (4 files)
#     |          |-------> 8337_attempt3
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533aeb0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3141317c0>]
#     |-------> ...
#
#     |-------> 9413_attempt1 (4 files)
#     |          |-------> 9413_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533a310>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3142c1f10>]
#     |-------> ...
#
#     |-------> 8385_attempt0 (4 files)
#     |          |-------> 8385_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17533a1c0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3150b9340>]
#     |-------> ...
#
#     |-------> 2192_attempt0 (4 files)
#     |          |-------> 2192_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531d880>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x316830ee0>]
#     |-------> ...
#
#     |-------> 4654_attempt0 (4 files)
#     |          |-------> 4654_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531db20>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x31413b6a0>]
#     |-------> ...
#
#     |-------> 8072_attempt1 (4 files)
#     |          |-------> 8072_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17531ddc0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3140352e0>]
#     |-------> ...

# %%
import pickle, bz2
import os
from hvo_sequence.hvo_seq import HVO_Sequence
# Load the loaded_hvos dictionary from a compressed file
def load_loaded_hvos_from_file(file_path):
    with bz2.BZ2File(file_path, "rb") as f:
        loaded_hvos = pickle.load(f)
    return loaded_hvos

loaded_hvos = load_loaded_hvos_from_file("data/triple_streams/split_2bars/elbg.pkl.bz2")
print(get_loaded_hvos_text_description(loaded_hvos))
# Out:
# Lack MIDI
#
# Dictionary Structure:
# AllAvailableStreams:
#     |-------> 8337_attempt3 (4 files)
#     |          |-------> 8337_attempt3
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3119775b0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3119778b0>]
#     |-------> ...
#
#     |-------> 9413_attempt1 (4 files)
#     |          |-------> 9413_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x315004a60>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x315004d60>]
#     |-------> ...
#
#     |-------> 8385_attempt0 (4 files)
#     |          |-------> 8385_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3170215b0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x317021760>]
#     |-------> ...
#
#     |-------> 2192_attempt0 (4 files)
#     |          |-------> 2192_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x317021fa0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x17682c9d0>]
#     |-------> ...
#
#     |-------> 4654_attempt0 (4 files)
#     |          |-------> 4654_attempt0
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x176178a90>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x1761782b0>]
#     |-------> ...
#
#     |-------> 8072_attempt1 (4 files)
#     |          |-------> 8072_attempt1
#     |                     |--> 'filenames:'
#     |                           |-------> flattened.hvo
#     |                           |-------> left.hvo
#     |                           |-------> both.hvo
#     |                           |-------> right.hvo
#     |                     |--> 'hvo_sequences:'
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                           |-------> 32 steps, i.e. 2 bars.
#     |                     |--> 'compiled_single_hvos:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x3131924f0>]
#     |                     |--> 'split_n_bar_phrases:'
#     |                               |-------> [<hvo_sequence.hvo_seq.HVO_Sequence object at 0x313192d00>]
#     |-------> ...

# %%
def get_random_set(loaded_hvos):
    """
    Get a random grouping type and a random file name from that grouping type.
    Returns the filenames and HVO sequences.
    """
    random_grouping_type = random.choice(list(loaded_hvos.keys()))
    random_file_name = random.choice(list(loaded_hvos[random_grouping_type].keys()))
    print(loaded_hvos[random_grouping_type][random_file_name]['compiled_single_hvos'][-1].metadata)
    return loaded_hvos[random_grouping_type][random_file_name]

streams_set_dict = get_random_set(loaded_hvos)

from bokeh.io import output_notebook, show
output_notebook()

streams_set_dict['split_n_bar_phrases'][0].to_html_plot(
    filename="hvo_1.html",
    save_figure=False,
    show_figure=True)
# Out:
# {'self_assesment': 1, 'genre': 'Soul', 'tempo': 102.0, 'experience': 4, 'instrument': 'right', 'participant_number': '3498', 'attempt': '0', 'stream_0': 'flattened', 'stream_1': 'left', 'stream_2': 'both', 'stream_3': 'right'}
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a9926a90-1d95-46d9-bb3f-c4ec0d31fc44">Loading BokehJS ...</span>
#     </div>
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
# BokehDeprecationWarning: 'circle() method with size value' was deprecated in Bokeh 3.4.0 and will be removed, use 'scatter(size=...) instead' instead.
#   <div id="a9dd3d49-cb84-4e7a-8f7c-4c70587671a0" data-root-id="p3664" style="display: contents;"></div>
# figure(id='p3664', ...)

# %%
streams_set_dict['split_n_bar_phrases'][1].to_html_plot(
    filename="hvo_1.html",
    save_figure=False,
    show_figure=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 streams_set_dict['split_n_bar_phrases'][1].to_html_plot(
#       2     filename="hvo_1.html",
#       3     save_figure=False,
#       4     show_figure=True)
#
# IndexError: list index out of range
