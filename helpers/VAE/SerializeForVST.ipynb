# %%
import wandb
import os
os.environ["WANDB_SILENT"] = "true"

import numpy as np
import pandas as pd

# import sys
# sys.path.insert(0, "../..")

# %cd ../..

from helpers import load_variational_mgt_model
from model import GrooveTransformerEncoderVAE
import torch

from umap import UMAP

from bokeh.palettes import inferno, Category20b
from bokeh.core.enums import MarkerType
from bokeh.plotting import figure, show, save
from bokeh.io import output_notebook, reset_output
# output_notebook()

from helpers.VAE.eval_utils import UMapper

def generate_umap(
        groove_transformer_vae, test_dataset, subset_name,
        collapse_tapped_sequence):
    """
    Generate the umap for the given model and dataset setting.
    Args:
        :param groove_transformer_vae: The model to be evaluated
        :param device: The device to be used for evaluation
        :param dataset_setting_json_path: The path to the dataset setting json file
        :param subset_name: The name of the subset to be evaluated
        :param collapse_tapped_sequence: Whether to collapse the tapped sequence or not (input will have 1 voice only)

    Returns:
        dictionary ready to be logged by wandb {f"{subset_name}_{umap}": wandb.Html}
    """

    # and model is correct type
    assert isinstance(groove_transformer_vae, GrooveTransformerEncoderVAE)

    in_groove = torch.tensor(
        np.array([hvo_seq.flatten_voices(reduce_dim=collapse_tapped_sequence)
                  for hvo_seq in test_dataset.hvo_sequences]), dtype=torch.float32)
        
    tags = [hvo_seq.metadata["style_primary"] for hvo_seq in test_dataset.hvo_sequences]

    _, _, _, latents_z = groove_transformer_vae.predict(in_groove, return_concatenated=True)

    umapper = UMapper(subset_name)
    umapper.fit(latents_z.detach().cpu().numpy(), tags_=tags)
    p = umapper.plot(show_plot=False, prepare_for_wandb=False)
    return {f"{subset_name}_umap": p}
# Out:
# /home/dtic

# %% [markdown]
# # Download model and load

# %%
run = wandb.init()
#nime2022_anon/mega_drum_no_balancing/model_epoch_140:v1
epoch = 140#190   #160
version = 1 #55 # 60
run_name = "wild-shape-9" #"rosy-sweep-51"       # f"apricot-sweep-56_ep{epoch}"

artifact_path = f"nime2022_anon/mega_drum_no_balancing/model_epoch_{epoch}:v{version}"
epoch = artifact_path.split("model_epoch_")[-1].split(":")[0]

artifact = run.use_artifact(artifact_path, type='model')
artifact_dir = artifact.download()
model = load_variational_mgt_model(os.path.join(artifact_dir, f"{epoch}.pth"))
# Out:
# Offset activation is sigmoid, bias is initialized to 0.5
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668522266657722, max=1.0…
# Offset activation is sigmoid, bias is initialized to 0.5

# %% [markdown]
# # Inspect Model (Visualize UMAP)

# %%
from data.src.dataLoaders import MonotonicGrooveDataset

test_dataset = MonotonicGrooveDataset(
        dataset_setting_json_path="data/dataset_json_settings/4_4_Beats_gmd.json",
        subset_tag="test",
        max_len=32,
        tapped_voice_idx=2,
        collapse_tapped_sequence=True,
        down_sampled_ratio=None,
        move_all_to_gpu=False
    )
# Out:
# INFO:data.Base.dataLoaders:Loading gmd dataset
# INFO:data.Base.dataLoaders:Loading Cached Version from: data/gmd/resources/cached/beat_division_factor_[4]/drum_mapping_label_ROLAND_REDUCED_MAPPING/beat_type_['beat']_time_signature_['4-4']
# 100%|██████████| 2054/2054 [00:00<00:00, 4770.19it/s]
# INFO:data.Base.dataLoaders:Loaded 2054 sequences
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 from data.src.dataLoaders import MonotonicGrooveDataset
# ----> 3 test_dataset = MonotonicGrooveDataset(
#       4         dataset_setting_json_path="data/dataset_json_settings/4_4_Beats_gmd.json",
#       5         subset_tag="test",
#       6         max_len=32,
#       7         tapped_voice_idx=2,
#       8         collapse_tapped_sequence=True,
#       9         down_sampled_ratio=None,
#      10         move_all_to_gpu=False
#      11     )
#
# File ~/Github/GrooveTransformer/data/src/dataLoaders.py:99, in MonotonicGrooveDataset.__init__(self, dataset_setting_json_path, subset_tag, max_len, tapped_voice_idx, collapse_tapped_sequence, load_as_tensor, sort_by_metadata_key, down_sampled_ratio, move_all_to_gpu, hit_loss_balancing_beta, genre_loss_balancing_beta)
#      95 # load pre-stored hvo_sequences or
#      96 #   a portion of them uniformly sampled if down_sampled_ratio is provided
#      97 # ------------------------------------------------------------------------------------------
#      98 if down_sampled_ratio is None:
# ---> 99     subset = load_bz2_hvo_sequences(dataset_setting_json_path, subset_tag, force_regenerate=False)
#     100 else:
#     101     subset = load_down_sampled_gmd_hvo_sequences(
#     102         dataset_setting_json_path=dataset_setting_json_path,
#     103         subset_tag=subset_tag,
#    (...)
#     106         cache_down_sampled_set=True
#     107     )
#
# File ~/Github/GrooveTransformer/data/src/dataLoaders.py:27, in load_bz2_hvo_sequences(dataset_setting_json_path, subset_tag, force_regenerate)
#      17 """
#      18 Loads the hvo_sequences using the settings provided in the json file.
#      19
#    (...)
#      23 :return:
#      24 """
#      26 # load settings
# ---> 27 dataset_setting_json = json.load(open(dataset_setting_json_path, "r"))
#      29 # load datasets
#      30 dataset_tags = [key for key in dataset_setting_json["settings"].keys()]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/dataset_json_settings/4_4_Beats_gmd.json'

# %%
umap = generate_umap(model, test_dataset, run_name, True)

try:
    reset_output()
    output_notebook()
    show(umap[f'{run_name}_umap'])
except:
    output_notebook()
    show(umap[f'{run_name}_umap'])
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1839">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1874">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="76877602-dd29-4f03-985d-a0c1e002d8b8" data-root-id="1002"></div>

# %% [markdown]
# # Serialize if meets your requirements

# %%
model.serialize(save_folder=f"{run_name}_{epoch}")
